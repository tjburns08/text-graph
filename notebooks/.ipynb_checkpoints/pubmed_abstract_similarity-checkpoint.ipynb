# %% [markdown]
# This notebook will take in a list of questions and calculate sentence similarity scores between each of them using the BERT model. We will begin by importing the dataset itself below. Credit for the "how-to" and code below goes to this [fantastic article](https://towardsdatascience.com/bert-for-measuring-text-similarity-eec91c6bf9e1). The main instruction is that the column with the text must be called 'text' for this script to work.

# %%
# Constants
dataset = 'pubmed_abstracts'
column = 'human_connectome'
model_name = 'all-mpnet-base-v2' #'dmis-lab/biobert-base-cased-v1.2' #'multi-qa-mpnet-base-dot-v1' # all-mpnet-base-v2
cutoff = 0.5 # Note that cutoffs differ depending on the model used. 0.5 for all-mpnet-base-v2

# %%
import pandas as pd
dat = pd.read_csv('../data/processed/' + dataset + '.csv')
dat
# Out:
#        Unnamed: 0                                      deep_learning  \
# 0               0  (['Magnetic resonance spectroscopic imaging (M...
# 1               1  (['Existing deep convolutional neural networks...
# 2               2  (['Deep learning techniques have been increasi...
# 3               3  (['The original article unfortunately containe...
# 4               4  (['The most common applications of artificial ...
# ...           ...                                                ...
# 13195       13195  (["Intact function of the Forkhead Box P2 (FOX...
# 13196       13196  (["Studies on ADHD in educational settings ind...
# 13197       13197  (['The mechanisms underlying cerebellar learni...
# 13198       13198  (['Withania somnifera root extract has been us...
# 13199       13199  (['Deep brain stimulation (DBS) has been found...
#
#                                                 covid_19  \
# 0      (['As cancer researchers shutter their labs to...
# 1      (['In December 2019, the outbreak of pneumonia...
# 2            ([], 'Treating COVID-19 with Chloroquine.')
# 3      (['18 years ago, in 2002, the world was astoni...
# 4      ([], 'Covid-19: Doctors still at "considerable...
# ...                                                  ...
# 13195                                                NaN
# 13196                                                NaN
# 13197                                                NaN
# 13198                                                NaN
# 13199                                                NaN
#
#                                         human_connectome  \
# 0      (['For decades, it has been largely unknown to...
# 1      (['While resting-state functional magnetic res...
# 2      (['This paper presents the experimental evalua...
# 3      ([], "For Microscopy special issue on 'connect...
# 4      (['A central feature of theories of spatial na...
# ...                                                  ...
# 13195                                                NaN
# 13196                                                NaN
# 13197                                                NaN
# 13198                                                NaN
# 13199                                                NaN
#
#                                          virtual_reality  \
# 0      (['To evaluate the differences between walking...
# 1      (['Potentially painful invasive procedures are...
# 2      (["Early exposure to radiological cross-sectio...
# 3      (['To investigate the effects of various rehab...
# 4      (['Virtual reality (VR) is a technology that a...
# ...                                                  ...
# 13195                                                NaN
# 13196                                                NaN
# 13197                                                NaN
# 13198                                                NaN
# 13199                                                NaN
#
#                                 brain_machine_interfaces  \
# 0      (['All neural information systems (NIS) rely o...
# 1      (['Independent component analysis (ICA) as a p...
# 2      ([], 'Brain-machine interfaces: assistive, tho...
# 3      (['While motor-imagery based brain-computer in...
# 4      (['The disorders of consciousness refer to cli...
# ...                                                  ...
# 13195                                                NaN
# 13196                                                NaN
# 13197                                                NaN
# 13198                                                NaN
# 13199                                                NaN
#
#                                   electroactive_polymers  \
# 0      (['A mediatorless glucose biosensor was develo...
# 1      (['Hierarchical structures of hybrid materials...
# 2      (['An analytical method was researched for the...
# 3      (['The antibacterial properties of a nanocompo...
# 4      (['The metal-mediated self-assembly of coordin...
# ...                                                  ...
# 13195                                                NaN
# 13196                                                NaN
# 13197                                                NaN
# 13198                                                NaN
# 13199                                                NaN
#
#                                         pedot_electrodes  \
# 0      (['In the growing field of brain-machine inter...
# 1      (['High-performance transparent and flexible t...
# 2      (['In this investigation, we employed a novel ...
# 3      (['Great progress has been made on the cyclabi...
# 4      (['With the aim of a reliable biosensing exhib...
# ...                                                  ...
# 13195                                                NaN
# 13196                                                NaN
# 13197                                                NaN
# 13198                                                NaN
# 13199                                                NaN
#
#                                         neuroprosthetics  \
# 0      (['The heart continuously and cyclically commu...
# 1      (['This study was aimed at investigating the i...
# 2      (['Low-intensity focused ultrasound stimulatio...
# 3      (['Our brain has developed a specific system t...
# 4      (["Electrophysiological techniques have improv...
# ...                                                  ...
# 13195                                                NaN
# 13196                                                NaN
# 13197                                                NaN
# 13198                                                NaN
# 13199                                                NaN
#
#                                 deep_learning_links  \
# 0      https://www.ncbi.nlm.nih.gov/pubmed/31352337
# 1      https://www.ncbi.nlm.nih.gov/pubmed/31329133
# 2      https://www.ncbi.nlm.nih.gov/pubmed/31329567
# 3      https://www.ncbi.nlm.nih.gov/pubmed/31350607
# 4      https://www.ncbi.nlm.nih.gov/pubmed/31348869
# ...                                             ...
# 13195  https://www.ncbi.nlm.nih.gov/pubmed/24964149
# 13196  https://www.ncbi.nlm.nih.gov/pubmed/25038149
# 13197  https://www.ncbi.nlm.nih.gov/pubmed/25289586
# 13198  https://www.ncbi.nlm.nih.gov/pubmed/25310001
# 13199  https://www.ncbi.nlm.nih.gov/pubmed/25101288
#
#                                      covid_19_links  \
# 0      https://www.ncbi.nlm.nih.gov/pubmed/32234716
# 1      https://www.ncbi.nlm.nih.gov/pubmed/32235387
# 2      https://www.ncbi.nlm.nih.gov/pubmed/32236562
# 3      https://www.ncbi.nlm.nih.gov/pubmed/32235085
# 4      https://www.ncbi.nlm.nih.gov/pubmed/32234713
# ...                                             ...
# 13195                                           NaN
# 13196                                           NaN
# 13197                                           NaN
# 13198                                           NaN
# 13199                                           NaN
#
#                              human_connectome_links  \
# 0      https://www.ncbi.nlm.nih.gov/pubmed/25420254
# 1      https://www.ncbi.nlm.nih.gov/pubmed/25589760
# 2      https://www.ncbi.nlm.nih.gov/pubmed/25624185
# 3      https://www.ncbi.nlm.nih.gov/pubmed/25652424
# 4      https://www.ncbi.nlm.nih.gov/pubmed/25601828
# ...                                             ...
# 13195                                           NaN
# 13196                                           NaN
# 13197                                           NaN
# 13198                                           NaN
# 13199                                           NaN
#
#                               virtual_reality_links  \
# 0      https://www.ncbi.nlm.nih.gov/pubmed/30653920
# 1      https://www.ncbi.nlm.nih.gov/pubmed/30679136
# 2      https://www.ncbi.nlm.nih.gov/pubmed/30697948
# 3      https://www.ncbi.nlm.nih.gov/pubmed/30686327
# 4      https://www.ncbi.nlm.nih.gov/pubmed/30668519
# ...                                             ...
# 13195                                           NaN
# 13196                                           NaN
# 13197                                           NaN
# 13198                                           NaN
# 13199                                           NaN
#
#                      brain_machine_interfaces_links  \
# 0      https://www.ncbi.nlm.nih.gov/pubmed/27669264
# 1      https://www.ncbi.nlm.nih.gov/pubmed/27631789
# 2      https://www.ncbi.nlm.nih.gov/pubmed/27654684
# 3      https://www.ncbi.nlm.nih.gov/pubmed/27578310
# 4      https://www.ncbi.nlm.nih.gov/pubmed/27590972
# ...                                             ...
# 13195                                           NaN
# 13196                                           NaN
# 13197                                           NaN
# 13198                                           NaN
# 13199                                           NaN
#
#                        electroactive_polymers_links  \
# 0      https://www.ncbi.nlm.nih.gov/pubmed/22967516
# 1      https://www.ncbi.nlm.nih.gov/pubmed/23545560
# 2      https://www.ncbi.nlm.nih.gov/pubmed/22265536
# 3      https://www.ncbi.nlm.nih.gov/pubmed/22091864
# 4      https://www.ncbi.nlm.nih.gov/pubmed/22624584
# ...                                             ...
# 13195                                           NaN
# 13196                                           NaN
# 13197                                           NaN
# 13198                                           NaN
# 13199                                           NaN
#
#                              pedot_electrodes_links  \
# 0      https://www.ncbi.nlm.nih.gov/pubmed/28266832
# 1      https://www.ncbi.nlm.nih.gov/pubmed/28937733
# 2      https://www.ncbi.nlm.nih.gov/pubmed/28825302
# 3      https://www.ncbi.nlm.nih.gov/pubmed/28306233
# 4      https://www.ncbi.nlm.nih.gov/pubmed/29201623
# ...                                             ...
# 13195                                           NaN
# 13196                                           NaN
# 13197                                           NaN
# 13198                                           NaN
# 13199                                           NaN
#
#                              neuroprosthetics_links
# 0      https://www.ncbi.nlm.nih.gov/pubmed/31051293
# 1      https://www.ncbi.nlm.nih.gov/pubmed/30655080
# 2      https://www.ncbi.nlm.nih.gov/pubmed/30952150
# 3      https://www.ncbi.nlm.nih.gov/pubmed/30685486
# 4      https://www.ncbi.nlm.nih.gov/pubmed/30564810
# ...                                             ...
# 13195                                           NaN
# 13196                                           NaN
# 13197                                           NaN
# 13198                                           NaN
# 13199                                           NaN
#
# [13200 rows x 17 columns]

# %% [markdown]
# Now we will isolate the questions as an array of sentences, which will be fed into a pre-trained "bert-base-nli-mean-tokens" model. We note that there was a "module not found" error in the code below. The maintainer of the sentence-transformers package fixed it and requires the user to install via "pip install -U sentence-transformers." The code below takes a while to run, as the pre-trained model is quite large. A menu of models is [here](https://www.sbert.net/docs/pretrained_models.html)

# %%
from sentence_transformers import SentenceTransformer

sentences = dat["text"].tolist()
model = SentenceTransformer(model_name)

sentence_embeddings = model.encode(sentences)
sentence_embeddings.shape
# Out:
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# (202, 768)

# %% [markdown]
# TODO Here, we make a topic model for our sentence similarity embedding. We will use the BERTopic library, [here](https://maartengr.github.io/BERTopic/index.html#quick-start)

# %% [markdown]
# From here, we're going to use cosine similarity to determine which questions are most similar to each other. One example of this is below. We compare the initial question to the first five questions after the initial question. We will display the questions and the similarity scores and see if it makes sense.

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

cos_sim = cosine_similarity(
    [sentence_embeddings[20]],
    sentence_embeddings
).tolist()

df = pd.DataFrame({'text': sentences,
            'similarity': cos_sim[0]})

# Arrange by similarity
pd.set_option('display.max_colwidth', None)
display(df.sort_values(by = 'similarity', ascending = False))
# Out:
#                                                                                                                                                                                                                                                                                         text  \
# 20                                                                                                                                                                                                 What do you think would be humanity’s reaction to the discovery of extraterrestrial life?
# 108                                                                                                                                                         If humanity was put on trial by an advanced race of aliens, how would you defend humanity and argue for its continued existence?
# 82                                                                                                               Would it be more frightening to discover that humans are the most advanced species in the universe or that we are far from being the most advanced species in the universe?
# 191                                                                                                                                                                                                                  What scientific breakthrough would have the biggest effect on humanity?
# 124                                                                                                                                          If it was discovered that most animals were conscious of their existence and eventual death, what would be the ramifications of that discovery?
# ..                                                                                                                                                                                                                                                                                       ...
# 95                                                                                                                                                       Why do we resist doing things that we know are good for our well-being while craving things that are detrimental to our well-being?
# 91                                                                                                                                                        Is it possible that someone’s genes might affect their political leanings? If no, why not? If so, what would be the ramifications?
# 24                                                                                                                                       Does hardship make a person stronger? If so, under what conditions and at what point is it too much hardship? If not, what makes a person stronger?
# 121                                                                                                  Can morality ever be objective or is it always subjective? If it can be objective, in what instances? If it’s always subjective, how do we decide whose concept of morality is correct?
# 90   Is the concept of “you” continuous or does past “you” continually fade into present and future “you”? In other words, what part of “you” sticks around over time considering that the atoms that make up your body are constantly being replaced and your memories are always changing?
#
#      similarity
# 20     1.000000
# 108    0.651333
# 82     0.607382
# 191    0.562743
# 124    0.558233
# ..          ...
# 95     0.207444
# 91     0.197444
# 24     0.159018
# 121    0.148967
# 90     0.120915
#
# [202 rows x 2 columns]

# %% [markdown]
# We were going to run a UMAP on the vector space to get some intuition around what it looks like, but because UMAP has issues with python 3.9 at the moment, we're going to jump right to making a cosine similarity matrix that we will then turn into a graph.

# %%
import sklearn

dist = sklearn.metrics.pairwise.cosine_distances(sentence_embeddings)
dist

# nn = sklearn.neighbors.kneighbors_graph(sentence_embeddings, n_neighbors = 1)
# nn
# Out:
# array([[0.        , 0.68917525, 0.67561233, ..., 0.7377938 , 0.64611244,
#         0.7612562 ],
#        [0.68917525, 0.        , 0.5191412 , ..., 0.6417422 , 0.5366794 ,
#         0.55929875],
#        [0.67561233, 0.5191412 , 0.        , ..., 0.7190081 , 0.6869738 ,
#         0.58177465],
#        ...,
#        [0.7377938 , 0.6417422 , 0.7190081 , ..., 0.        , 0.7546375 ,
#         0.5302633 ],
#        [0.64611244, 0.5366794 , 0.6869738 , ..., 0.7546375 , 0.        ,
#         0.5702214 ],
#        [0.7612562 , 0.55929875, 0.58177465, ..., 0.5302633 , 0.5702214 ,
#         0.        ]], dtype=float32)

# %%
import igraph as ig
import matplotlib.pyplot as plt

dist = np.where(dist == 0, 1, dist) # For the boolean below. Can't figure out compound boolean.

g = ig.Graph.Adjacency(dist < cutoff) # Need to convert to boolean
g = g.as_undirected()

if dat.shape[0] < 1000:
    fig, ax = plt.subplots()
    ig.plot(g, target=ax)

# %% [markdown]
# Now we will do a quick measure of betweenness and eigenvector centrality to get a feel for what questions are the most central. We'll print the top 10 of each.

# %%
deg = g.degree()
btw = g.betweenness()
dat['degree'] = g.degree()
dat['betweenness'] = g.betweenness()
display(dat.sort_values(by='degree', ascending=False))
display(dat.sort_values(by='betweenness', ascending=False))
# Out:
#            Person                       Source  \
# 43   C.B. Daniels  Conversation Starters World
# 56   C.B. Daniels  Conversation Starters World
# 168  C.B. Daniels  Conversation Starters World
# 189  C.B. Daniels  Conversation Starters World
# 6    C.B. Daniels  Conversation Starters World
# ..            ...                          ...
# 141  C.B. Daniels  Conversation Starters World
# 140  C.B. Daniels  Conversation Starters World
# 139  C.B. Daniels  Conversation Starters World
# 137  C.B. Daniels  Conversation Starters World
# 0    C.B. Daniels  Conversation Starters World
#
#                                                                Link  \
# 43   https://conversationstartersworld.com/philosophical-questions/
# 56   https://conversationstartersworld.com/philosophical-questions/
# 168  https://conversationstartersworld.com/philosophical-questions/
# 189  https://conversationstartersworld.com/philosophical-questions/
# 6    https://conversationstartersworld.com/philosophical-questions/
# ..                                                              ...
# 141  https://conversationstartersworld.com/philosophical-questions/
# 140  https://conversationstartersworld.com/philosophical-questions/
# 139  https://conversationstartersworld.com/philosophical-questions/
# 137  https://conversationstartersworld.com/philosophical-questions/
# 0    https://conversationstartersworld.com/philosophical-questions/
#
#                                                                                                                text  \
# 43                                                        What is the most important goal every person should have?
# 56                                    What would you genetically change about humans to make them a better species?
# 168                                                     What is the most important right our government allows for?
# 189                              Is technological progress inevitable as long as humans exist or can it be stopped?
# 6                                                                            What does it mean to live a good life?
# ..                                                                                                              ...
# 141  If I steal a loaf of bread from you and eat it, when does the bread itself cease to be yours and becomes mine?
# 140                                    How does this human trait of morality dependent on distance shape our world?
# 139       Why are humans so fascinated by mass murderers if their actions are universally considered evil and vile?
# 137                                                                                What is your definition of evil?
# 0                                                                        What harsh truths do you prefer to ignore?
#
#      degree  betweenness
# 43       10  3211.773810
# 56        9  1044.125000
# 168       9  1584.690476
# 189       7   238.833333
# 6         7   886.761905
# ..      ...          ...
# 141       0     0.000000
# 140       0     0.000000
# 139       0     0.000000
# 137       0     0.000000
# 0         0     0.000000
#
# [202 rows x 6 columns]
#            Person                       Source  \
# 43   C.B. Daniels  Conversation Starters World
# 168  C.B. Daniels  Conversation Starters World
# 191  C.B. Daniels  Conversation Starters World
# 56   C.B. Daniels  Conversation Starters World
# 42   C.B. Daniels  Conversation Starters World
# ..            ...                          ...
# 93   C.B. Daniels  Conversation Starters World
# 94   C.B. Daniels  Conversation Starters World
# 95   C.B. Daniels  Conversation Starters World
# 96   C.B. Daniels  Conversation Starters World
# 101  C.B. Daniels  Conversation Starters World
#
#                                                                Link  \
# 43   https://conversationstartersworld.com/philosophical-questions/
# 168  https://conversationstartersworld.com/philosophical-questions/
# 191  https://conversationstartersworld.com/philosophical-questions/
# 56   https://conversationstartersworld.com/philosophical-questions/
# 42   https://conversationstartersworld.com/philosophical-questions/
# ..                                                              ...
# 93   https://conversationstartersworld.com/philosophical-questions/
# 94   https://conversationstartersworld.com/philosophical-questions/
# 95   https://conversationstartersworld.com/philosophical-questions/
# 96   https://conversationstartersworld.com/philosophical-questions/
# 101  https://conversationstartersworld.com/philosophical-questions/
#
#                                                                                                                                                                                                             text  \
# 43                                                                                                                                                     What is the most important goal every person should have?
# 168                                                                                                                                                  What is the most important right our government allows for?
# 191                                                                                                                                      What scientific breakthrough would have the biggest effect on humanity?
# 56                                                                                                                                 What would you genetically change about humans to make them a better species?
# 42                                                                                                          What life-altering things should every human ideally get to experience at least once in their lives?
# ..                                                                                                                                                                                                           ...
# 93   Would selectively breeding an animal such as a dog based on intelligence, increase its intelligence over time? If so, how intelligent could dogs become? If not, how does intelligence emerge in a species?
# 94                                                                                                                                                                         Are there limits to human creativity?
# 95                                                                           Why do we resist doing things that we know are good for our well-being while craving things that are detrimental to our well-being?
# 96           Is it be possible for humans to create something completely novel and new that is based on nothing that previously existed? Or is human creativity just rearranging and building on previous ideas?
# 101                                                                                                                                 Is a sense of humor a byproduct of consciousness or something else entirely?
#
#      degree  betweenness
# 43       10  3211.773810
# 168       9  1584.690476
# 191       7  1235.275000
# 56        9  1044.125000
# 42        5  1037.250000
# ..      ...          ...
# 93        0     0.000000
# 94        2     0.000000
# 95        0     0.000000
# 96        2     0.000000
# 101       1     0.000000
#
# [202 rows x 6 columns]

# %% [markdown]
# From here, we run clustering to see if the the quesitons group into particular themes. We will use Louvain clustering, as it is often used in graph-based analysis.

# %%
clust = ig.Graph.community_multilevel(g)
#df = pd.DataFrame({'name': dat['Question'], 'cluster': clust.membership})
dat['cluster'] = clust.membership

# Get cluster ID, mine the per-cluster topics
for i in pd.unique(dat['cluster']):
    curr = dat[dat['cluster'] == i]
    if curr.shape[0] > 5:
        display(curr.sort_values(by='degree', ascending=False))
# Out:
#            Person                       Source  \
# 6    C.B. Daniels  Conversation Starters World
# 19   C.B. Daniels  Conversation Starters World
# 33   C.B. Daniels  Conversation Starters World
# 54   C.B. Daniels  Conversation Starters World
# 2    C.B. Daniels  Conversation Starters World
# 58   C.B. Daniels  Conversation Starters World
# 69   C.B. Daniels  Conversation Starters World
# 60   C.B. Daniels  Conversation Starters World
# 74   C.B. Daniels  Conversation Starters World
# 102  C.B. Daniels  Conversation Starters World
# 23   C.B. Daniels  Conversation Starters World
# 37   C.B. Daniels  Conversation Starters World
# 62   C.B. Daniels  Conversation Starters World
#
#                                                                Link  \
# 6    https://conversationstartersworld.com/philosophical-questions/
# 19   https://conversationstartersworld.com/philosophical-questions/
# 33   https://conversationstartersworld.com/philosophical-questions/
# 54   https://conversationstartersworld.com/philosophical-questions/
# 2    https://conversationstartersworld.com/philosophical-questions/
# 58   https://conversationstartersworld.com/philosophical-questions/
# 69   https://conversationstartersworld.com/philosophical-questions/
# 60   https://conversationstartersworld.com/philosophical-questions/
# 74   https://conversationstartersworld.com/philosophical-questions/
# 102  https://conversationstartersworld.com/philosophical-questions/
# 23   https://conversationstartersworld.com/philosophical-questions/
# 37   https://conversationstartersworld.com/philosophical-questions/
# 62   https://conversationstartersworld.com/philosophical-questions/
#
#                                                                                                                                                                                         text  \
# 6                                                                                                                                                     What does it mean to live a good life?
# 19                                                                                                                                                   Where do you find meaning in your life?
# 33                                                                                                                                    What is the best way for a person to attain happiness?
# 54                                                                                                                What activities cause you to feel like you are living life to the fullest?
# 2                                                                                                                                             Is there a meaning to life? If so, what is it?
# 58   Where do you think is the most worthwhile place to find meaning in life? Work, family, hobby, religion, philosophy, helping others, all the small miracles, or something else entirely?
# 69                                                                                                   What is the best path to find truth; science, math, art, philosophy, or something else?
# 60                                                                              Is a life that focuses on avoiding pain and seeking out pleasure a good and worthwhile life? Why or why not?
# 74                                                                                                                 Is happiness just chemicals flowing through your brain or something more?
# 102                                            Are intelligence and happiness tied together in any way? If you are highly intelligent, is it more likely that you’ll be more, or less happy?
# 23                                                                                       Is suffering a necessary part of the human condition? What would people who never suffered be like?
# 37                                                                                                                                                    Is intelligence or wisdom more useful?
# 62                                                                    What percentage of your life do you feel truly alive? When do you feel that way? How can you feel that way more often?
#
#      degree  betweenness  cluster
# 6         7   886.761905        2
# 19        7   154.452381        2
# 33        6   498.928571        2
# 54        5   124.952381        2
# 2         4   649.452381        2
# 58        4    18.166667        2
# 69        3    12.309524        2
# 60        2   100.000000        2
# 74        2   198.000000        2
# 102       2   100.000000        2
# 23        1     0.000000        2
# 37        1     0.000000        2
# 62        1     0.000000        2
#            Person                       Source  \
# 163  C.B. Daniels  Conversation Starters World
# 26   C.B. Daniels  Conversation Starters World
# 39   C.B. Daniels  Conversation Starters World
# 166  C.B. Daniels  Conversation Starters World
# 169  C.B. Daniels  Conversation Starters World
# 161  C.B. Daniels  Conversation Starters World
# 3    C.B. Daniels  Conversation Starters World
# 176  C.B. Daniels  Conversation Starters World
# 182  C.B. Daniels  Conversation Starters World
#
#                                                                Link  \
# 163  https://conversationstartersworld.com/philosophical-questions/
# 26   https://conversationstartersworld.com/philosophical-questions/
# 39   https://conversationstartersworld.com/philosophical-questions/
# 166  https://conversationstartersworld.com/philosophical-questions/
# 169  https://conversationstartersworld.com/philosophical-questions/
# 161  https://conversationstartersworld.com/philosophical-questions/
# 3    https://conversationstartersworld.com/philosophical-questions/
# 176  https://conversationstartersworld.com/philosophical-questions/
# 182  https://conversationstartersworld.com/philosophical-questions/
#
#                                                                                                                                                                                                                             text  \
# 163                                                                                                                  Is the cultural trend of individualism and the rejection of collectivism a beneficial or detrimental trend?
# 26                                                                                                                                                     What benefits does art provide society? Does art hurt society in any way?
# 39                                                                                                                                                                                       What do you contribute back to society?
# 166                                                                                                                                                                 What are the benefits and drawbacks of diversity in society?
# 169                                                                                                                                                 Has social media been a net positive or a net negative for our society? Why?
# 161                                                                                                        Is the human tendency to create groups an overall positive or a negative trait in terms of general human flourishing?
# 3                                                                                                                                                                                     Where is the line between art and not art?
# 176                                                                                                                             Will humanity ever be able to escape tribalism and the creation of in and out groups? Should it?
# 182  Was the agricultural revolution and the explosion of civilizations that came from it an overall good thing for humans or a negative? In other words, would it have been better or worse for people to stay in small tribes?
#
#      degree  betweenness  cluster
# 163       5      337.625        3
# 26        4      133.125        3
# 39        3      301.600        3
# 166       3       99.625        3
# 169       3       74.625        3
# 161       2      100.000        3
# 3         1        0.000        3
# 176       1        0.000        3
# 182       1        0.000        3
#            Person                       Source  \
# 43   C.B. Daniels  Conversation Starters World
# 56   C.B. Daniels  Conversation Starters World
# 191  C.B. Daniels  Conversation Starters World
# 4    C.B. Daniels  Conversation Starters World
# 22   C.B. Daniels  Conversation Starters World
# 42   C.B. Daniels  Conversation Starters World
# 18   C.B. Daniels  Conversation Starters World
# 47   C.B. Daniels  Conversation Starters World
# 31   C.B. Daniels  Conversation Starters World
# 45   C.B. Daniels  Conversation Starters World
# 118  C.B. Daniels  Conversation Starters World
# 145  C.B. Daniels  Conversation Starters World
# 194  C.B. Daniels  Conversation Starters World
#
#                                                                Link  \
# 43   https://conversationstartersworld.com/philosophical-questions/
# 56   https://conversationstartersworld.com/philosophical-questions/
# 191  https://conversationstartersworld.com/philosophical-questions/
# 4    https://conversationstartersworld.com/philosophical-questions/
# 22   https://conversationstartersworld.com/philosophical-questions/
# 42   https://conversationstartersworld.com/philosophical-questions/
# 18   https://conversationstartersworld.com/philosophical-questions/
# 47   https://conversationstartersworld.com/philosophical-questions/
# 31   https://conversationstartersworld.com/philosophical-questions/
# 45   https://conversationstartersworld.com/philosophical-questions/
# 118  https://conversationstartersworld.com/philosophical-questions/
# 145  https://conversationstartersworld.com/philosophical-questions/
# 194  https://conversationstartersworld.com/philosophical-questions/
#
#                                                                                                                                                                      text  \
# 43                                                                                                              What is the most important goal every person should have?
# 56                                                                                          What would you genetically change about humans to make them a better species?
# 191                                                                                               What scientific breakthrough would have the biggest effect on humanity?
# 4                                                                                                                                    What should be the goal of humanity?
# 22                                                 If you could teach everyone in the world one concept, what concept would have the biggest positive impact on humanity?
# 42                                                                   What life-altering things should every human ideally get to experience at least once in their lives?
# 18                                                  How would humanity change if all humans’ life expectancy was significantly increased (let’s say to around 500 years)?
# 47                                                                                                                     Can human nature be changed? Should it be changed?
# 31                                                                                                                    Is humanity headed in the right or wrong direction?
# 45                                                                                                                                     What are you capable of achieving?
# 118                                                                                                                 Are people ethically obligated to improve themselves?
# 145                                                                                               Would the world be a better or worse place if everyone looked the same?
# 194  If a robust and cheap genetic engineering industry existed, would you have your genes edited? If so, what genetic changes would you choose to make? If not, why not?
#
#      degree  betweenness  cluster
# 43       10  3211.773810        4
# 56        9  1044.125000        4
# 191       7  1235.275000        4
# 4         5   657.250000        4
# 22        5   560.250000        4
# 42        5  1037.250000        4
# 18        3   173.666667        4
# 47        2   100.000000        4
# 31        1     0.000000        4
# 45        1     0.000000        4
# 118       1     0.000000        4
# 145       1     0.000000        4
# 194       1     0.000000        4
#           Person                       Source  \
# 75  C.B. Daniels  Conversation Starters World
# 38  C.B. Daniels  Conversation Starters World
# 84  C.B. Daniels  Conversation Starters World
# 86  C.B. Daniels  Conversation Starters World
# 7   C.B. Daniels  Conversation Starters World
# 51  C.B. Daniels  Conversation Starters World
# 88  C.B. Daniels  Conversation Starters World
#
#                                                               Link  \
# 75  https://conversationstartersworld.com/philosophical-questions/
# 38  https://conversationstartersworld.com/philosophical-questions/
# 84  https://conversationstartersworld.com/philosophical-questions/
# 86  https://conversationstartersworld.com/philosophical-questions/
# 7   https://conversationstartersworld.com/philosophical-questions/
# 51  https://conversationstartersworld.com/philosophical-questions/
# 88  https://conversationstartersworld.com/philosophical-questions/
#
#                                                                                            text  \
# 75                                           Why are humans so susceptible to magical thinking?
# 38                                   Which of your beliefs are justified and which ones aren’t?
# 84  So, which of your beliefs are most likely to be wrong and which are most liable to be true?
# 86                                 Why are humans so confident in beliefs that can’t be proven?
# 7                                                                              Why do we dream?
# 51                          Which is a more valid point of view or are they both equally valid?
# 88             Why do humans have such a strong urge to distract ourselves from the real world?
#
#     degree  betweenness  cluster
# 75       3          9.0        5
# 38       2          5.0        5
# 84       2          8.0        5
# 86       2          9.0        5
# 7        1          0.0        5
# 51       1          0.0        5
# 88       1          0.0        5
#            Person                       Source  \
# 72   C.B. Daniels  Conversation Starters World
# 8    C.B. Daniels  Conversation Starters World
# 46   C.B. Daniels  Conversation Starters World
# 53   C.B. Daniels  Conversation Starters World
# 64   C.B. Daniels  Conversation Starters World
# 121  C.B. Daniels  Conversation Starters World
# 122  C.B. Daniels  Conversation Starters World
# 138  C.B. Daniels  Conversation Starters World
#
#                                                                Link  \
# 72   https://conversationstartersworld.com/philosophical-questions/
# 8    https://conversationstartersworld.com/philosophical-questions/
# 46   https://conversationstartersworld.com/philosophical-questions/
# 53   https://conversationstartersworld.com/philosophical-questions/
# 64   https://conversationstartersworld.com/philosophical-questions/
# 121  https://conversationstartersworld.com/philosophical-questions/
# 122  https://conversationstartersworld.com/philosophical-questions/
# 138  https://conversationstartersworld.com/philosophical-questions/
#
#                                                                                                                                                                                         text  \
# 72                                                                                                                                       What in life is truly objective and not subjective?
# 8                                                                                                                                                      Where does your self-worth come from?
# 46                                                                                                                                                  By what standards do you judge yourself?
# 53                                                                                                            Why do we judge ourselves by our intentions but judge others by their actions?
# 64                                                                           With that in mind, what are the most important things to learn about one’s self or is all self-knowledge equal?
# 121  Can morality ever be objective or is it always subjective? If it can be objective, in what instances? If it’s always subjective, how do we decide whose concept of morality is correct?
# 122                                                                                                        Are intentions or outcomes more important when judging whether actions are moral?
# 138                                                                                Do all people have equal value regardless of their actions or is a person’s value based on their actions?
#
#      degree  betweenness  cluster
# 72        4   425.333333        6
# 8         3    62.833333        6
# 46        3   296.000000        6
# 53        3   199.000000        6
# 64        2    67.000000        6
# 121       1     0.000000        6
# 122       1     0.000000        6
# 138       1     0.000000        6
#            Person                       Source  \
# 189  C.B. Daniels  Conversation Starters World
# 188  C.B. Daniels  Conversation Starters World
# 201  C.B. Daniels  Conversation Starters World
# 193  C.B. Daniels  Conversation Starters World
# 9    C.B. Daniels  Conversation Starters World
# 27   C.B. Daniels  Conversation Starters World
# 81   C.B. Daniels  Conversation Starters World
# 94   C.B. Daniels  Conversation Starters World
# 96   C.B. Daniels  Conversation Starters World
# 192  C.B. Daniels  Conversation Starters World
# 186  C.B. Daniels  Conversation Starters World
# 190  C.B. Daniels  Conversation Starters World
#
#                                                                Link  \
# 189  https://conversationstartersworld.com/philosophical-questions/
# 188  https://conversationstartersworld.com/philosophical-questions/
# 201  https://conversationstartersworld.com/philosophical-questions/
# 193  https://conversationstartersworld.com/philosophical-questions/
# 9    https://conversationstartersworld.com/philosophical-questions/
# 27   https://conversationstartersworld.com/philosophical-questions/
# 81   https://conversationstartersworld.com/philosophical-questions/
# 94   https://conversationstartersworld.com/philosophical-questions/
# 96   https://conversationstartersworld.com/philosophical-questions/
# 192  https://conversationstartersworld.com/philosophical-questions/
# 186  https://conversationstartersworld.com/philosophical-questions/
# 190  https://conversationstartersworld.com/philosophical-questions/
#
#                                                                                                                                                                                                                      text  \
# 189                                                                                                                                    Is technological progress inevitable as long as humans exist or can it be stopped?
# 188                                                                                                                                                        Is technological advancement a net positive or a net negative?
# 201                                                                                                                                            Is there a limit to what humans can create through technology and science?
# 193      Will we keep leaping to even greater technological and scientific breakthroughs that radically change society, or will the rate of progress slow and humanity’s progress be limited to incremental improvements?
# 9                                                                                                                                                                                How will humans as a species go extinct?
# 27                                                                                                            How likely do you think it will be that humans will last another 1,000 years without killing ourselves off?
# 81   Assuming evolution is correct, do you think that if humans went extinct another species as intelligent as humans would evolve? If life exists long enough on a planet, is intelligence and consciousness inevitable?
# 94                                                                                                                                                                                  Are there limits to human creativity?
# 96                    Is it be possible for humans to create something completely novel and new that is based on nothing that previously existed? Or is human creativity just rearranging and building on previous ideas?
# 192                                                                                                                                                 Why did technology progress more slowly in the past than it does now?
# 186                                                                                                                                                At what point is a technologically enhanced human not a human anymore?
# 190                                                                                                                      Is true artificial intelligence possible with our current technology and methods of programming?
#
#      degree  betweenness  cluster
# 189       7   238.833333        7
# 188       6   656.566667        7
# 201       5   296.000000        7
# 193       4   456.916667        7
# 9         3     7.500000        7
# 27        3    92.666667        7
# 81        3     7.500000        7
# 94        2     0.000000        7
# 96        2     0.000000        7
# 192       2     0.000000        7
# 186       1     0.000000        7
# 190       1     0.000000        7
#            Person                       Source  \
# 78   C.B. Daniels  Conversation Starters World
# 106  C.B. Daniels  Conversation Starters World
# 12   C.B. Daniels  Conversation Starters World
# 80   C.B. Daniels  Conversation Starters World
# 110  C.B. Daniels  Conversation Starters World
# 29   C.B. Daniels  Conversation Starters World
# 77   C.B. Daniels  Conversation Starters World
# 124  C.B. Daniels  Conversation Starters World
# 89   C.B. Daniels  Conversation Starters World
# 104  C.B. Daniels  Conversation Starters World
# 66   C.B. Daniels  Conversation Starters World
# 79   C.B. Daniels  Conversation Starters World
# 83   C.B. Daniels  Conversation Starters World
# 101  C.B. Daniels  Conversation Starters World
#
#                                                                Link  \
# 78   https://conversationstartersworld.com/philosophical-questions/
# 106  https://conversationstartersworld.com/philosophical-questions/
# 12   https://conversationstartersworld.com/philosophical-questions/
# 80   https://conversationstartersworld.com/philosophical-questions/
# 110  https://conversationstartersworld.com/philosophical-questions/
# 29   https://conversationstartersworld.com/philosophical-questions/
# 77   https://conversationstartersworld.com/philosophical-questions/
# 124  https://conversationstartersworld.com/philosophical-questions/
# 89   https://conversationstartersworld.com/philosophical-questions/
# 104  https://conversationstartersworld.com/philosophical-questions/
# 66   https://conversationstartersworld.com/philosophical-questions/
# 79   https://conversationstartersworld.com/philosophical-questions/
# 83   https://conversationstartersworld.com/philosophical-questions/
# 101  https://conversationstartersworld.com/philosophical-questions/
#
#                                                                                                                                                       text  \
# 78                                                                                                                        How do you define consciousness?
# 106                                                                                                                               Can animals have morals?
# 12                                                                                                 Is the meaning of life the same for animals and humans?
# 80                                                                                                                 How conscious do you think animals are?
# 110                        Do animals have rights and do those rights extend to all animals or do the rights change based on the complexity of the animal?
# 29                                                                     If freedom is simply being able to do what you want, are animals freer than humans?
# 77                                                                 Is it possible that some animals are self-aware and think about their ability to think?
# 124        If it was discovered that most animals were conscious of their existence and eventual death, what would be the ramifications of that discovery?
# 89                                                                                  What is the benefit of consciousness from an evolutionary stand point?
# 104                   With that in mind, what is real and what is just our perception of reality? Or does every organism live in its own personal reality?
# 66   Is math something that humans created or something we discovered? Is looking at reality mathematically an accurate representation of how things work?
# 79                                                                          Is it possible to prove that other people besides yourself have consciousness?
# 83                                                                                                                            How would you define genius?
# 101                                                                           Is a sense of humor a byproduct of consciousness or something else entirely?
#
#      degree  betweenness  cluster
# 78        6   520.166667       10
# 106       5   910.000000       10
# 12        4   579.309524       10
# 80        4   668.333333       10
# 110       4   513.976190       10
# 29        3     0.000000       10
# 77        3    76.666667       10
# 124       3    62.833333       10
# 89        2     3.000000       10
# 104       2   100.000000       10
# 66        1     0.000000       10
# 79        1     0.000000       10
# 83        1     0.000000       10
# 101       1     0.000000       10
#            Person                       Source  \
# 105  C.B. Daniels  Conversation Starters World
# 41   C.B. Daniels  Conversation Starters World
# 130  C.B. Daniels  Conversation Starters World
# 131  C.B. Daniels  Conversation Starters World
# 125  C.B. Daniels  Conversation Starters World
# 148  C.B. Daniels  Conversation Starters World
# 120  C.B. Daniels  Conversation Starters World
#
#                                                                Link  \
# 105  https://conversationstartersworld.com/philosophical-questions/
# 41   https://conversationstartersworld.com/philosophical-questions/
# 130  https://conversationstartersworld.com/philosophical-questions/
# 131  https://conversationstartersworld.com/philosophical-questions/
# 125  https://conversationstartersworld.com/philosophical-questions/
# 148  https://conversationstartersworld.com/philosophical-questions/
# 120  https://conversationstartersworld.com/philosophical-questions/
#
#                                                                                                                                     text  \
# 105                                                                                     When, if ever, is taking a human life justified?
# 41                                        Is it more important to help yourself, help your family, help your society, or help the world?
# 130         If you can save another’s life and don’t because doing so would break the law, are you ethically justified in your decision?
# 131  Are all individuals morally obligated to save another person’s life if they are able? What if that person lives in another country?
# 125                                                                                          Should euthanasia be legal? Why or why not?
# 148                                          Do people in wealthier countries have a moral obligation to help those in poorer countries?
# 120                       At what point is overthrowing a government ethical, considering all the violence a revolution usually entails?
#
#      degree  betweenness  cluster
# 105       4       149.00       25
# 41        3       878.35       25
# 130       3        49.00       25
# 131       3       388.00       25
# 125       2         0.00       25
# 148       2       480.00       25
# 120       1         0.00       25
#            Person                       Source  \
# 168  C.B. Daniels  Conversation Starters World
# 119  C.B. Daniels  Conversation Starters World
# 123  C.B. Daniels  Conversation Starters World
# 149  C.B. Daniels  Conversation Starters World
# 167  C.B. Daniels  Conversation Starters World
# 109  C.B. Daniels  Conversation Starters World
# 147  C.B. Daniels  Conversation Starters World
# 154  C.B. Daniels  Conversation Starters World
# 173  C.B. Daniels  Conversation Starters World
# 177  C.B. Daniels  Conversation Starters World
# 197  C.B. Daniels  Conversation Starters World
# 142  C.B. Daniels  Conversation Starters World
# 144  C.B. Daniels  Conversation Starters World
# 180  C.B. Daniels  Conversation Starters World
# 181  C.B. Daniels  Conversation Starters World
#
#                                                                Link  \
# 168  https://conversationstartersworld.com/philosophical-questions/
# 119  https://conversationstartersworld.com/philosophical-questions/
# 123  https://conversationstartersworld.com/philosophical-questions/
# 149  https://conversationstartersworld.com/philosophical-questions/
# 167  https://conversationstartersworld.com/philosophical-questions/
# 109  https://conversationstartersworld.com/philosophical-questions/
# 147  https://conversationstartersworld.com/philosophical-questions/
# 154  https://conversationstartersworld.com/philosophical-questions/
# 173  https://conversationstartersworld.com/philosophical-questions/
# 177  https://conversationstartersworld.com/philosophical-questions/
# 197  https://conversationstartersworld.com/philosophical-questions/
# 142  https://conversationstartersworld.com/philosophical-questions/
# 144  https://conversationstartersworld.com/philosophical-questions/
# 180  https://conversationstartersworld.com/philosophical-questions/
# 181  https://conversationstartersworld.com/philosophical-questions/
#
#                                                                                                                                           text  \
# 168                                                                                What is the most important right our government allows for?
# 119                                                                                                                        Is privacy a right?
# 123                                                                                   Should there be limitations on the right to free speech?
# 149                                                   What should the role of a government be, what boundaries and limitations should it have?
# 167                         Under our government are there any rights that you have but shouldn’t? How about rights you don’t have but should?
# 109                                                                    What rights does every human have? Do those rights change based on age?
# 147                                                     How far should governments go to prevent its citizens from causing harm to themselves?
# 154                                                                          What is the biggest threat to the social contract in our country?
# 173  In an ideal government, what should a good citizen provide to their government and what should that government provide that good citizen?
# 177                                                                                  How much privacy are you willing to sacrifice for safety?
# 197                                                                           Should full access to the internet be a fundamental human right?
# 142                                                                        How much effort should an individual put into not offending others?
# 144                           Would a government run with algorithms, A.I., and statistics be better or worse than the government we have now?
# 180                                                                                                    Is some degree of censorship necessary?
# 181                                                                            What are the biggest moral dilemmas your country is facing now?
#
#      degree  betweenness  cluster
# 168       9  1584.690476       49
# 119       5   101.000000       49
# 123       4   100.000000       49
# 149       4   288.500000       49
# 167       4    30.000000       49
# 109       3   569.309524       49
# 147       3   102.500000       49
# 154       2   100.000000       49
# 173       2     0.000000       49
# 177       2     6.000000       49
# 197       2     0.000000       49
# 142       1     0.000000       49
# 144       1     0.000000       49
# 180       1     0.000000       49
# 181       1     0.000000       49
#            Person                       Source  \
# 162  C.B. Daniels  Conversation Starters World
# 143  C.B. Daniels  Conversation Starters World
# 152  C.B. Daniels  Conversation Starters World
# 185  C.B. Daniels  Conversation Starters World
# 150  C.B. Daniels  Conversation Starters World
# 175  C.B. Daniels  Conversation Starters World
#
#                                                                Link  \
# 162  https://conversationstartersworld.com/philosophical-questions/
# 143  https://conversationstartersworld.com/philosophical-questions/
# 152  https://conversationstartersworld.com/philosophical-questions/
# 185  https://conversationstartersworld.com/philosophical-questions/
# 150  https://conversationstartersworld.com/philosophical-questions/
# 175  https://conversationstartersworld.com/philosophical-questions/
#
#                                                                                                                                      text  \
# 162  What would happen to a society in which no one had to work, and everyone was provided enough food/water/shelter/healthcare for free?
# 143                                                                     If you could start a country from scratch, what would it be like?
# 152                                                             What would a utopia be like, how would it function and continue to exist?
# 185             If you were given the ability to reform how your country’s leaders were chosen and how they serve, what would you change?
# 150                                                                                                     Is poverty in society inevitable?
# 175                                                                                                     Can a society exist without laws?
#
#      degree  betweenness  cluster
# 162       4        199.0       68
# 143       3        388.0       68
# 152       2          0.0       68
# 185       2        480.0       68
# 150       1          0.0       68
# 175       1          0.0       68

# %% [markdown]
# Now, we're going to pull the graph out as an edgelist and get a feel for who is connected to who. We will then export the edgelist for import into Neo4J.
#
# TODO 1) make this a searchable umap. 2) place this into neo4j 3) set up the virtual environemnt and stop installing anything to the regular environemnt

# %%
el = g.get_edge_dataframe()
el
# Out:
#          source  target
# edge ID
# 0             1       5
# 1             2       6
# 2             2      12
# 3            15      16
# 4             2      19
# ...         ...     ...
# 165          94     201
# 166          96     201
# 167         189     201
# 168         190     201
# 169         193     201
#
# [170 rows x 2 columns]

# %% [markdown]
# Now we have to convert the edges from their edge IDs to the questions that are in the order of the IDs. The reason we're seeing numbers right now is that the original adjacency matrix was made with the IDs and not the questions themselves. We're going to do that using a simple conversion function. We're going to do this by creating a dictionary.

# %%
q_dict = {}

for i in range(0, len(sentences)):
    q_dict[i] = sentences[i]
# Out:
# {0: 'What harsh truths do you prefer to ignore?',
#  1: 'Is free will real or just an illusion?',
#  2: 'Is there a meaning to life? If so, what is it?',
#  3: 'Where is the line between art and not art?',
#  4: 'What should be the goal of humanity?',
#  5: 'Does fate exist? If so, do we have free will?',
#  6: 'What does it mean to live a good life?',
#  7: 'Why do we dream?',
#  8: 'Where does your self-worth come from?',
#  9: 'How will humans as a species go extinct?',
#  10: 'Is it possible to live a normal life and not ever tell a lie?',
#  11: 'Does a person’s name influence the person they become?',
#  12: 'Is the meaning of life the same for animals and humans?',
#  13: 'If someone you loved was killed in front of you, but someone created a copy of them that was perfect right down to the atomic level, would they be the same person and would you love them just as much?',
#  14: 'If you could become immortal on the condition you would NEVER be able to die or kill yourself, would you choose immortality?',
#  15: 'What actions in your life will have the longest reaching consequences? How long will those effects be felt?',
#  16: 'How long will you be remembered after you die?',
#  17: 'If a child somehow survived and grew up in the wilderness without any human contact, how “human” would they be without the influence of society and culture?',
#  18: 'How would humanity change if all humans’ life expectancy was significantly increased (let’s say to around 500 years)?',
#  19: 'Where do you find meaning in your life?',
#  20: 'What do you think would be humanity’s reaction to the discovery of extraterrestrial life?',
#  21: 'Will religion ever become obsolete?',
#  22: 'If you could teach everyone in the world one concept, what concept would have the biggest positive impact on humanity?',
#  23: 'Is suffering a necessary part of the human condition? What would people who never suffered be like?',
#  24: 'Does hardship make a person stronger? If so, under what conditions and at what point is it too much hardship? If not, what makes a person stronger?',
#  25: 'Would things get better or worse if humans focused on what was going well rather than what’s going wrong?',
#  26: 'What benefits does art provide society? Does art hurt society in any way?',
#  27: 'How likely do you think it will be that humans will last another 1,000 years without killing ourselves off?',
#  28: 'What do you attribute the biggest successes in your life to? How about your largest failures?',
#  29: 'If freedom is simply being able to do what you want, are animals freer than humans?',
#  30: 'Would you want to know you are going to die before hand or die suddenly without warning?',
#  31: 'Is humanity headed in the right or wrong direction?',
#  32: 'Does the study of philosophy ever lead to answers or simply more questions?',
#  33: 'What is the best way for a person to attain happiness?',
#  34: 'If you had to guess, what do you think would be the most likely way you’ll die?',
#  35: 'Is it better for a person to have a broad knowledge base or a deep knowledge base?',
#  36: 'What is the best way to train people to see the gradients in the world around them instead of just a simplistic “this is good, that is wrong” view of the world?',
#  37: 'Is intelligence or wisdom more useful?',
#  38: 'Which of your beliefs are justified and which ones aren’t?',
#  39: 'What do you contribute back to society?',
#  40: 'What are you going to do with the one life you have?',
#  41: 'Is it more important to help yourself, help your family, help your society, or help the world?',
#  42: 'What life-altering things should every human ideally get to experience at least once in their lives?',
#  43: 'What is the most important goal every person should have?',
#  44: 'Is it better to be a big fish in a small pond or a small fish in a big pond?',
#  45: 'What are you capable of achieving?',
#  46: 'By what standards do you judge yourself?',
#  47: 'Can human nature be changed? Should it be changed?',
#  48: 'How replaceable are you?',
#  49: 'Why don’t we as a species take more advantage of the fact that we have almost infinite knowledge available to us?',
#  50: 'What two questions would you ask to get the most information about who a person truly is?',
#  51: 'Which is a more valid point of view or are they both equally valid?',
#  52: 'Does absolute power corrupt absolutely?',
#  53: 'Why do we judge ourselves by our intentions but judge others by their actions?',
#  54: 'What activities cause you to feel like you are living life to the fullest?',
#  55: 'Does knowledge have intrinsic value or does it need to have a practical use to have value?',
#  56: 'What would you genetically change about humans to make them a better species?',
#  57: 'How important is play in living a healthy and fulfilling life?',
#  58: 'Where do you think is the most worthwhile place to find meaning in life? Work, family, hobby, religion, philosophy, helping others, all the small miracles, or something else entirely?',
#  59: 'What is the biggest waste of human potential?',
#  60: 'Is a life that focuses on avoiding pain and seeking out pleasure a good and worthwhile life? Why or why not?',
#  61: 'Does jealously have value in driving humans to improve themselves or is it a purely negative emotion?',
#  62: 'What percentage of your life do you feel truly alive? When do you feel that way? How can you feel that way more often?',
#  63: 'What do you think your future self will remember about you now?',
#  64: 'With that in mind, what are the most important things to learn about one’s self or is all self-knowledge equal?',
#  65: 'What do you think existed before the universe was created?',
#  66: 'Is math something that humans created or something we discovered? Is looking at reality mathematically an accurate representation of how things work?',
#  67: 'Is it possible for a human to fathom the true depths of reality and existence?',
#  68: 'If the universe is finite, what would beyond the edge of the universe be like?',
#  69: 'What is the best path to find truth; science, math, art, philosophy, or something else?',
#  70: 'Is this something temporary and our minds will adapt and begin to understand this new reality or is it possible that the human mind will soon reach its limits of comprehension? If it’s only temporary, is there is a limit to what the human mind can comprehend? If we are reaching our limits, how do we continue to study our reality?',
#  71: 'Is there inherent order in nature or is it all chaos and chance?',
#  72: 'What in life is truly objective and not subjective?',
#  73: 'Which do you think is more likely?',
#  74: 'Is happiness just chemicals flowing through your brain or something more?',
#  75: 'Why are humans so susceptible to\xa0magical thinking?',
#  76: 'If every neuron in a human was accurately simulated in a computer, would it result in human consciousness?',
#  77: 'Is it possible that some animals are self-aware and think about their ability to think?',
#  78: 'How do you define consciousness?',
#  79: 'Is it possible to prove that other people besides yourself have consciousness?',
#  80: 'How conscious do you think animals are?',
#  81: 'Assuming evolution is correct, do you think that if humans went extinct another species as intelligent as humans would evolve? If life exists long enough on a planet, is intelligence and consciousness inevitable?',
#  82: 'Would it be more frightening to discover that humans are the most advanced species in the universe or that we are far from being the most advanced species in the universe?',
#  83: 'How would you define genius?',
#  84: 'So, which of your beliefs are most likely to be wrong and which are most liable to be true?',
#  85: 'How much does language affect our thinking?',
#  86: 'Why are humans so confident in beliefs that can’t be proven?',
#  87: 'If all your memories were erased, what kind of person would you be?',
#  88: 'Why do humans have such a strong urge to distract ourselves from the real world?',
#  89: 'What is the benefit of consciousness from an evolutionary stand point?',
#  90: 'Is the concept of “you” continuous or does past “you” continually fade into present and future “you”? In other words, what part of “you” sticks around over time considering that the atoms that make up your body are constantly being replaced and your memories are always changing?',
#  91: 'Is it possible that someone’s genes might affect their political leanings? If no, why not? If so, what would be the ramifications?',
#  92: 'Can rational thought exist without language?',
#  93: 'Would selectively breeding an animal such as a dog based on intelligence, increase its intelligence over time? If so, how intelligent could dogs become? If not, how does intelligence emerge in a species?',
#  94: 'Are there limits to human creativity?',
#  95: 'Why do we resist doing things that we know are good for our well-being while craving things that are detrimental to our well-being?',
#  96: 'Is it be possible for humans to create something completely novel and new that is based on nothing that previously existed? Or is human creativity just rearranging and building on previous ideas?',
#  97: 'If there existed a perfect clone of you, would it also be you? Would it act in exactly the same manner as you (like a mirror) or would it act differently? If it acted differently then would it still be you? At what point would it not be you?',
#  98: 'Would you be able to tell if time had been altered in some way?',
#  99: 'What would it be like if humans could perceive what the world is actually like and do it in real time? Also, what are the ramifications of every single person’s reality being a little different and unique to them?',
#  100: 'If\xa0language influences how we perceive color, what other things could languages be changing our perception of?',
#  101: 'Is a sense of humor a byproduct of consciousness or something else entirely?',
#  102: 'Are intelligence and happiness tied together in any way? If you are highly intelligent, is it more likely that you’ll be more, or less happy?',
#  103: 'With that in mind, how do you know which of your memories are genuine and which have been altered or made up?',
#  104: 'With that in mind, what is real and what is just our perception of reality? Or does every organism live in its own personal reality?',
#  105: 'When, if ever, is taking a human life justified?',
#  106: 'Can animals have morals?',
#  107: 'Without religion would people become more, less, or be equally morally corrupt?',
#  108: 'If humanity was put on trial by an advanced race of aliens, how would you defend humanity and argue for its continued existence?',
#  109: 'What rights does every human have? Do those rights change based on age?',
#  110: 'Do animals have rights and do those rights extend to all animals or do the rights change based on the complexity of the animal?',
#  111: 'Is justice a human construct or is it independent of humans?',
#  112: 'Why do people expect a universe full of randomness to be fair?',
#  113: 'With no laws or rules to influence your behavior, how do you think you would behave?',
#  114: 'What’s the difference between justice and revenge?',
#  115: 'If it was discovered that personality traits were partly genetic and could be removed with gene therapy, would it be ethical to edit out negative character traits that harm others like extreme aggression, compulsive lying, or cruelty?',
#  116: 'If you could press a button and receive a million dollars, but one stranger would die, would you press the button? And if so, how many times?',
#  117: 'What would be the most ethical way to give away five million dollars?',
#  118: 'Are people ethically obligated to improve themselves?',
#  119: 'Is privacy a right?',
#  120: 'At what point is overthrowing a government ethical, considering all the violence a revolution usually entails?',
#  121: 'Can morality ever be objective or is it always subjective? If it can be objective, in what instances? If it’s always subjective, how do we decide whose concept of morality is correct?',
#  122: 'Are intentions or outcomes more important when judging whether actions are moral?',
#  123: 'Should there be limitations on the right to free speech?',
#  124: 'If it was discovered that most animals were conscious of their existence and eventual death, what would be the ramifications of that discovery?',
#  125: 'Should euthanasia be legal? Why or why not?',
#  126: 'If scientists could accurately predict who was more likely to commit crimes, what should society do with that information?',
#  127: 'Do business owners have the right to refuse service to customers?',
#  128: 'If babies are considered innocent, when do people cease to be innocent?',
#  129: 'Why do humans often associate beauty with morality?',
#  130: 'If you can save another’s life and don’t because doing so would break the law, are you ethically justified in your decision?',
#  131: 'Are all individuals morally obligated to save another person’s life if they are able? What if that person lives in another country?',
#  132: 'Is it just and right to deny entry to a country when doing so probably means death for the immigrant and their family?',
#  133: 'Should we terraform planets if it means that we may be destroying undiscovered microscopic alien life?',
#  134: 'Does anonymity encourage people to misbehave or does it reveal how people would choose to act all the time if they could?',
#  135: 'What is the most fertile soil for hatred? Fear, ignorance, jealousy, or something else entirely? Is it possible that some people are genetically predisposed to hatred?',
#  136: 'If doing something good for others makes us feel good, can there ever be such a thing as pure altruism?',
#  137: 'What is your definition of evil?',
#  138: 'Do all people have equal value regardless of their actions or is a person’s value based on their actions?',
#  139: 'Why are humans so fascinated by mass murderers if their actions are universally considered evil and vile?',
#  140: 'How does this human trait of morality dependent on distance shape our world?',
#  141: 'If I steal a loaf of bread from you and eat it, when does the bread itself cease to be yours and becomes mine?',
#  142: 'How much effort should an individual put into not offending others?',
#  143: 'If you could start a country from scratch, what would it be like?',
#  144: 'Would a government run with algorithms, A.I., and statistics be better or worse than the government we have now?',
#  145: 'Would the world be a better or worse place if everyone looked the same?',
#  146: 'What causes the most harm in the world, but is completely avoidable?',
#  147: 'How far should governments go to prevent its citizens from causing harm to themselves?',
#  148: 'Do people in wealthier countries have a moral obligation to help those in poorer countries?',
#  149: 'What should the role of a government be, what boundaries and limitations should it have?',
#  150: 'Is poverty in society inevitable?',
#  151: 'How should we measure the productivity of a society?',
#  152: 'What would a utopia be like, how would it function and continue to exist?',
#  153: 'Do you think there will ever be a global government? If a world government did come to power, assuming it wasn’t particularly cruel or evil, would it be a good or bad thing?',
#  154: 'What is the biggest threat to the social contract in our country?',
#  155: 'Is it more or less difficult to be successful in the modern world than it was in the past (10, 50, 100, or 1,000 years ago)?',
#  156: 'without money or a barter system)?',
#  157: 'What would happen if a maximum income of was implemented?',
#  158: 'What will the economy of wealthy countries look like in 50 to 100 years?',
#  159: 'What do you think the long-term effects of so many people being glued to their screens will be?',
#  160: 'If all humans want the same basic things, why is there so much violence and strife between people?',
#  161: 'Is the human tendency to create groups an overall positive or a negative trait in terms of general human flourishing?',
#  162: 'What would happen to a society in which no one had to work, and everyone was provided enough food/water/shelter/healthcare for free?',
#  163: 'Is the cultural trend of individualism and the rejection of collectivism a beneficial or detrimental trend?',
#  164: 'Considering that the technology exists to enable a real democracy, would a true democracy (every single person can vote on every single legislation) be advantageous or detrimental?',
#  165: 'If everyone said what they were actually thinking, what would happen to society?',
#  166: 'What are the benefits and drawbacks of diversity in society?',
#  167: 'Under our government are there any rights that you have but shouldn’t? How about rights you don’t have but should?',
#  168: 'What is the most important right our government allows for?',
#  169: 'Has social media been a net positive or a net negative for our society? Why?',
#  170: 'How would society change if men were able to get pregnant and men and women both had an equal chance of getting pregnant?',
#  171: 'Why have many societies begun to place such a high value on emotions and being emotional?',
#  172: 'Is it right or wrong that everyone seems to be accustomed to the fact that all of humanity and most of the life on Earth could be wiped out at the whim of a handful of people?',
#  173: 'In an ideal government, what should a good citizen provide to their government and what should that government provide that good citizen?',
#  174: 'Should tax payers have the option to explicitly say what they don’t want their tax dollars spent on?',
#  175: 'Can a society exist without laws?',
#  176: 'Will humanity ever be able to escape tribalism and the creation of in and out groups? Should it?',
#  177: 'How much privacy are you willing to sacrifice for safety?',
#  178: 'How would the world change if there was an accurate measure of aptitude?',
#  179: 'Is hierarchy necessary for all successful human communities?',
#  180: 'Is some degree of censorship necessary?',
#  181: 'What are the biggest moral dilemmas your country is facing now?',
#  182: 'Was the agricultural revolution and the explosion of civilizations that came from it an overall good thing for humans or a negative? In other words, would it have been better or worse for people to stay in small tribes?',
#  183: 'What will be/are some of the by-products to society of everyone having the ability to take pictures or a video at any time?',
#  184: 'Does marriage as an institution need to be updated or is it fine how it is?',
#  185: 'If you were given the ability to reform how your country’s leaders were chosen and how they serve, what would you change?',
#  186: 'At what point is a technologically enhanced human not a human anymore?',
#  187: 'Does the modern age make global conspiracies more or less feasible?',
#  188: 'Is technological advancement a net positive or a net negative?',
#  189: 'Is technological progress inevitable as long as humans exist or can it be stopped?',
#  190: 'Is true artificial intelligence possible with our current technology and methods of programming?',
#  191: 'What scientific breakthrough would have the biggest effect on humanity?',
#  192: 'Why did technology progress more slowly in the past than it does now?',
#  193: 'Will we keep leaping to even greater technological and scientific breakthroughs that radically change society, or will the rate of progress slow and humanity’s progress be limited to incremental improvements?',
#  194: 'If a robust and cheap genetic engineering industry existed, would you have your genes edited? If so, what genetic changes would you choose to make? If not, why not?',
#  195: 'Given a scale from completely human to completely machine, how far would you choose to augment yourself with robotics? What parts would you augment and why?',
#  196: 'If the transporters in Star Trek existed and you used it, your particles would be disassembled and then reassembled, do you die every single time? Are you ever alive at two places at once? Are you ever completely dead?',
#  197: 'Should full access to the internet be a fundamental human right?',
#  198: 'Has the invention of the atomic bomb made the world a more peaceful place?',
#  199: 'Do you think the singularity will occur? If so, what time frame do you think it will happen in?',
#  200: 'If we could control emotions through technology, should we?',
#  201: 'Is there a limit to what humans can create through technology and science?'}

# %%
e1 = [q_dict[i] for i in el['source']]
e2 = [q_dict[i] for i in el['target']]

el_df = pd.DataFrame({'edge1': e1, 'edge2': e2})
el_df
# Out:
#                                                                                                                                                                                                                 edge1  \
# 0                                                                                                                                                                              Is free will real or just an illusion?
# 1                                                                                                                                                                      Is there a meaning to life? If so, what is it?
# 2                                                                                                                                                                      Is there a meaning to life? If so, what is it?
# 3                                                                                                         What actions in your life will have the longest reaching consequences? How long will those effects be felt?
# 4                                                                                                                                                                      Is there a meaning to life? If so, what is it?
# ..                                                                                                                                                                                                                ...
# 165                                                                                                                                                                             Are there limits to human creativity?
# 166               Is it be possible for humans to create something completely novel and new that is based on nothing that previously existed? Or is human creativity just rearranging and building on previous ideas?
# 167                                                                                                                                Is technological progress inevitable as long as humans exist or can it be stopped?
# 168                                                                                                                  Is true artificial intelligence possible with our current technology and methods of programming?
# 169  Will we keep leaping to even greater technological and scientific breakthroughs that radically change society, or will the rate of progress slow and humanity’s progress be limited to incremental improvements?
#
#                                                                           edge2
# 0                                 Does fate exist? If so, do we have free will?
# 1                                        What does it mean to live a good life?
# 2                       Is the meaning of life the same for animals and humans?
# 3                                How long will you be remembered after you die?
# 4                                       Where do you find meaning in your life?
# ..                                                                          ...
# 165  Is there a limit to what humans can create through technology and science?
# 166  Is there a limit to what humans can create through technology and science?
# 167  Is there a limit to what humans can create through technology and science?
# 168  Is there a limit to what humans can create through technology and science?
# 169  Is there a limit to what humans can create through technology and science?
#
# [170 rows x 2 columns]

# %%
el_df.to_csv('../output/' + dataset + '_' + model_name + '_edgelist_dist_' + str(cutoff) + '.csv', encoding='utf-8-sig')
dat.to_csv('../output/' + dataset + '_' + model_name + '_analyzed_' + str(cutoff) + '.csv', encoding='utf-8-sig')
#model_out.to_csv('../output/' + dataset + '_topic_model' + str(cutoff) + '.csv', encoding='utf-8-sig')
