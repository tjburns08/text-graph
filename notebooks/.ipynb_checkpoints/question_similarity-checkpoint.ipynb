# %% [markdown]
# This notebook will take in a list of questions and calculate sentence similarity scores between each of them using the BERT model. We will begin by importing the dataset itself below. Credit for the "how-to" and code below goes to this [fantastic article](https://towardsdatascience.com/bert-for-measuring-text-similarity-eec91c6bf9e1). The main instruction is that the column with the text must be called 'text' for this script to work.

# %%
# Constants
dev = False
dataset = 'curated_personal_development_questions' 
column = 'Question' 
model_name = 'all-mpnet-base-v2' #'dmis-lab/biobert-base-cased-v1.2' #'multi-qa-mpnet-base-dot-v1' # all-mpnet-base-v2
cutoff = 0.55 # Note that cutoffs differ depending on the model used. 0.5 for all-mpnet-base-v2

# %%
import pandas as pd
dat = pd.read_csv('../data/' + dataset + '.csv')

if dev == True:
    dat = dat.head(20)
    
display(dat.shape)
display(dat)
# Out:
# (104, 4)
#                       Person                             Source  \
# 0                Tim Ferriss  17 questions that changed my life
# 1                Tim Ferriss  17 questions that changed my life
# 2                Tim Ferriss  17 questions that changed my life
# 3                Tim Ferriss  17 questions that changed my life
# 4                Tim Ferriss  17 questions that changed my life
# ..                       ...                                ...
# 99   Daniel Schmachtenberger                    Dharma Inquiiry
# 100  Daniel Schmachtenberger                    Dharma Inquiiry
# 101  Daniel Schmachtenberger                    Dharma Inquiiry
# 102  Daniel Schmachtenberger                    Dharma Inquiiry
# 103  Daniel Schmachtenberger                    Dharma Inquiiry
#
#                                                                                   Link  \
# 0    https://tim.blog/wp-content/uploads/2020/01/17-Questions-That-Changed-My-Life.pdf
# 1    https://tim.blog/wp-content/uploads/2020/01/17-Questions-That-Changed-My-Life.pdf
# 2    https://tim.blog/wp-content/uploads/2020/01/17-Questions-That-Changed-My-Life.pdf
# 3    https://tim.blog/wp-content/uploads/2020/01/17-Questions-That-Changed-My-Life.pdf
# 4    https://tim.blog/wp-content/uploads/2020/01/17-Questions-That-Changed-My-Life.pdf
# ..                                                                                 ...
# 99                                    https://civilizationemerging.com/dharma-inquiry/
# 100                                   https://civilizationemerging.com/dharma-inquiry/
# 101                                   https://civilizationemerging.com/dharma-inquiry/
# 102                                   https://civilizationemerging.com/dharma-inquiry/
# 103                                   https://civilizationemerging.com/dharma-inquiry/
#
#                                                                                    Question
# 0                                                  What if I did the opposite for 48 hours?
# 1              What do I spend a silly amount of money on? How might I scratch my own itch?
# 2                         What would I do/have/be if I had $10 million? What’s my real TMI?
# 3                       What are the worst things that could happen? Could I get back here?
# 4                    If I could only work 2 hours per week on my business, what would I do?
# ..                                                                                      ...
# 99                              What do I do that I wouldn’t want to be fully honest about?
# 100  What parts of my life would not engender the respect of those whom I respect the most?
# 101                                 Where is my success occurring at the expense of others?
# 102                                                    Where does my life feel imbalanced?
# 103   What do I do because I’m good at it but don’t really like it or care about it deeply?
#
# [104 rows x 4 columns]

# %% [markdown]
# Now we will isolate the questions as an array of sentences, which will be fed into a pre-trained user-specified model. We note that there was a "module not found" error in the code below. The maintainer of the sentence-transformers package fixed it and requires the user to install via "pip install -U sentence-transformers." The code below takes a while to run, as the pre-trained model is quite large. A menu of models is [here](https://www.sbert.net/docs/pretrained_models.html)

# %%
from sentence_transformers import SentenceTransformer

sentences = dat[column].tolist()
model = SentenceTransformer(model_name)

sentence_embeddings = model.encode(sentences)
sentence_embeddings.shape
# Out:
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# (104, 768)

# %% [markdown]
# Here, we make a topic model for our sentence similarity embedding. We will use the BERTopic library, [here](https://maartengr.github.io/BERTopic/index.html#quick-start)

# %% [markdown]
# From here, we're going to use cosine similarity to determine which questions are most similar to each other. One example of this is below. We compare the initial question to the first five questions after the initial question. We will display the questions and the similarity scores and see if it makes sense.

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

cos_sim = cosine_similarity(
    [sentence_embeddings[20]],
    sentence_embeddings
).tolist()

df = pd.DataFrame({'text': sentences,
            'distance': cos_sim[0]})

df['distance'] = 1 - df['distance']

# Arrange by similarity
pd.set_option('display.max_colwidth', None)
display(df.sort_values(by = 'distance', ascending = True))
# Out:
#                                                                                                                                                                                                                                                                                                                             text  \
# 20                                                                                                                                                                                                            What purchase of $100 or less has most positively impacted your life in the last six months (or in recent memory)?
# 26                                                                                                                                                                                                                                      In the last five years, what new belief, behavior, or habit has most improved your life?
# 24                                                                                                                                                                                                                                                      What is one of the best or most worthwhile investments you’ve ever made?
# 18                                                                                                                                                                                                                                                             What is the book (or books) you’ve given most as a gift, and why?
# 1                                                                                                                                                                                                                                                   What do I spend a silly amount of money on? How might I scratch my own itch?
# ..                                                                                                                                                                                                                                                                                                                           ...
# 33                                                                                                                                                                                                With the first fully globalized civilization, how do we avoid the collapse fate that has befallen all previous civilizations?
# 14                                                                                                                                                                                                                                                                                          Am I hunting antelope or field mice?
# 3                                                                                                                                                                                                                                                            What are the worst things that could happen? Could I get back here?
# 12                                                                                                                                                                                                                                                           What are the worst things that could happen? Could I get back here?
# 34  How do we do adequate safety analysis on radically unprecedented, complex, and consequential technologies like artificial intelligence and synthetic biology? Moreover, how do we bind the development of these technologies to those safety analyses and ensure that they are neither weaponized nor deployed negligently?
#
#     distance
# 20  0.000000
# 26  0.348258
# 24  0.355284
# 18  0.504933
# 1   0.531461
# ..       ...
# 33  0.994047
# 14  0.997881
# 3   1.006318
# 12  1.006318
# 34  1.033913
#
# [104 rows x 2 columns]

# %% [markdown]
# We were going to run a UMAP on the vector space to get some intuition around what it looks like, but because UMAP has issues with python 3.9 at the moment, we're going to jump right to making a cosine similarity matrix that we will then turn into a graph.

# %%
import sklearn

dist = sklearn.metrics.pairwise.cosine_distances(sentence_embeddings)
dist

# nn = sklearn.neighbors.kneighbors_graph(sentence_embeddings, n_neighbors = 1)
# nn
# Out:
# array([[0.        , 0.9511144 , 0.7835439 , ..., 0.8549266 , 0.90494514,
#         0.8651454 ],
#        [0.9511144 , 0.        , 0.5410053 , ..., 0.80248547, 0.8379752 ,
#         0.70464665],
#        [0.7835439 , 0.5410053 , 0.        , ..., 0.83068615, 0.85354537,
#         0.77937025],
#        ...,
#        [0.8549266 , 0.80248547, 0.83068615, ..., 0.        , 0.5620159 ,
#         0.7481234 ],
#        [0.90494514, 0.8379752 , 0.85354537, ..., 0.5620159 , 0.        ,
#         0.7568787 ],
#        [0.8651454 , 0.70464665, 0.77937025, ..., 0.7481234 , 0.7568787 ,
#         0.        ]], dtype=float32)

# %%
import igraph as ig
import matplotlib.pyplot as plt

dist = np.where(dist == 0, 1, dist) # For the boolean below. Can't figure out compound boolean.

g = ig.Graph.Adjacency(dist < cutoff) # Need to convert to boolean
g = g.as_undirected()

if dat.shape[0] <= 1000:
    fig, ax = plt.subplots()
    ig.plot(g, target=ax)

# %% [markdown]
# Now we will do a quick measure of betweenness and eigenvector centrality to get a feel for what questions are the most central. We'll print the top 10 of each.

# %%
deg = g.degree()
btw = g.betweenness()
dat['degree'] = g.degree()
dat['betweenness'] = g.betweenness()
display(dat.sort_values(by='degree', ascending=False))
display(dat.sort_values(by='betweenness', ascending=False))
# Out:
#                       Person                             Source  \
# 82   Daniel Schmachtenberger                    Dharma Inquiiry
# 100  Daniel Schmachtenberger                    Dharma Inquiiry
# 93   Daniel Schmachtenberger                    Dharma Inquiiry
# 62   Daniel Schmachtenberger                    Dharma Inquiiry
# 53   Daniel Schmachtenberger                    Dharma Inquiiry
# ..                       ...                                ...
# 10               Tim Ferriss  17 questions that changed my life
# 16               Tim Ferriss  17 questions that changed my life
# 11               Tim Ferriss  17 questions that changed my life
# 15               Tim Ferriss  17 questions that changed my life
# 8                Tim Ferriss  17 questions that changed my life
#
#                                                                                   Link  \
# 82                                    https://civilizationemerging.com/dharma-inquiry/
# 100                                   https://civilizationemerging.com/dharma-inquiry/
# 93                                    https://civilizationemerging.com/dharma-inquiry/
# 62                                    https://civilizationemerging.com/dharma-inquiry/
# 53                                    https://civilizationemerging.com/dharma-inquiry/
# ..                                                                                 ...
# 10   https://tim.blog/wp-content/uploads/2020/01/17-Questions-That-Changed-My-Life.pdf
# 16   https://tim.blog/wp-content/uploads/2020/01/17-Questions-That-Changed-My-Life.pdf
# 11   https://tim.blog/wp-content/uploads/2020/01/17-Questions-That-Changed-My-Life.pdf
# 15   https://tim.blog/wp-content/uploads/2020/01/17-Questions-That-Changed-My-Life.pdf
# 8    https://tim.blog/wp-content/uploads/2020/01/17-Questions-That-Changed-My-Life.pdf
#
#                                                                                                                                                                           Question  \
# 82                                                                            What do I enjoy doing for its own sake, independent of producing results or getting acknowledgement?
# 100                                                                                         What parts of my life would not engender the respect of those whom I respect the most?
# 93   Where are there incongruences in my self, between my values and my actions…between some desires and other desires…between my habits and the expression of my highest vision…?
# 62                                                                                                       What virtues would you most want to increase in yourself? Why those ones?
# 53                                                                              If I was meaningfully smarter than I currently am, what would I do and how would I be differently?
# ..                                                                                                                                                                             ...
# 10                                                                                                                                    Do I need to make it back the way I lost it?
# 16                                                                                                                                      What would this look like if it were easy?
# 11                                                                                                                                What if I could only subtract to solve problems?
# 15                                                                                                                         Could it be that everything is fine and complete as is?
# 8                                                                                                                                    What if I couldn’t pitch my product directly?
#
#      degree  betweenness
# 82       17   330.975079
# 100      16   597.144853
# 93       15   322.190908
# 62       14   411.558873
# 53       13   177.072530
# ..      ...          ...
# 10        0     0.000000
# 16        0     0.000000
# 11        0     0.000000
# 15        0     0.000000
# 8         0     0.000000
#
# [104 rows x 6 columns]
#                       Person                 Source  \
# 40   Daniel Schmachtenberger  Civilization Emerging
# 36   Daniel Schmachtenberger  Civilization Emerging
# 71   Daniel Schmachtenberger        Dharma Inquiiry
# 100  Daniel Schmachtenberger        Dharma Inquiiry
# 45   Daniel Schmachtenberger  Civilization Emerging
# ..                       ...                    ...
# 75   Daniel Schmachtenberger        Dharma Inquiiry
# 29               Tim Ferriss       Tribe of Mentors
# 35   Daniel Schmachtenberger  Civilization Emerging
# 30               Tim Ferriss       Tribe of Mentors
# 57   Daniel Schmachtenberger        Dharma Inquiiry
#
#                                                  Link  \
# 40                  https://civilizationemerging.com/
# 36                  https://civilizationemerging.com/
# 71   https://civilizationemerging.com/dharma-inquiry/
# 100  https://civilizationemerging.com/dharma-inquiry/
# 45                  https://civilizationemerging.com/
# ..                                                ...
# 75   https://civilizationemerging.com/dharma-inquiry/
# 29      https://tim.blog/2017/10/03/tribe-of-mentors/
# 35                  https://civilizationemerging.com/
# 30      https://tim.blog/2017/10/03/tribe-of-mentors/
# 57   https://civilizationemerging.com/dharma-inquiry/
#
#                                                                                                                                                                    Question  \
# 40                                                              How can we change the topology of incentive landscapes in the direction towards long term life enhancement?
# 36                                                                                         How would we best identify and remove perverse economic interests systemically?
# 71                                                                                                                           What would you sacrifice personal benefit for?
# 100                                                                                  What parts of my life would not engender the respect of those whom I respect the most?
# 45                                                      How do we comprehensively disincentivize misinformation and harm to the information ecology and epistemic commons?
# ..                                                                                                                                                                      ...
# 75                                                                                                                                     What is the basis of meaningfulness?
# 29   In the last five years, what have you become better at saying no to (distractions, invitations, etc.)? What new realizations and/or approaches helped? Any other tips?
# 35                                                                                 How would we best identify and internalize externalities in the decision making process?
# 30                           When you feel overwhelmed or unfocused, or have lost your focus temporarily, what do you do? (If helpful: What questions do you ask yourself?)
# 57                                                                             If my main character deficits were resolved, what would I do and how would I be differently?
#
#      degree  betweenness
# 40        3   915.430505
# 36        6   889.000000
# 71        8   836.798257
# 100      16   597.144853
# 45        4   542.000000
# ..      ...          ...
# 75        1     0.000000
# 29        0     0.000000
# 35        1     0.000000
# 30        3     0.000000
# 57        7     0.000000
#
# [104 rows x 6 columns]

# %% [markdown]
# From here, we run clustering to see if the the quesitons group into particular themes. We will use Louvain clustering, as it is often used in graph-based analysis.

# %%
clust = ig.Graph.community_multilevel(g)
#df = pd.DataFrame({'name': dat['Question'], 'cluster': clust.membership})
dat['cluster'] = clust.membership

# Get cluster ID, mine the per-cluster topics
for i in pd.unique(dat['cluster']):
    curr = dat[dat['cluster'] == i]
    if curr.shape[0] > 5:
        display(curr.sort_values(by='degree', ascending=False))
# Out:
#                      Person                             Source  \
# 69  Daniel Schmachtenberger                    Dharma Inquiiry
# 78  Daniel Schmachtenberger                    Dharma Inquiiry
# 24              Tim Ferriss                   Tribe of Mentors
# 48  Daniel Schmachtenberger                    Dharma Inquiiry
# 49  Daniel Schmachtenberger                    Dharma Inquiiry
# 1               Tim Ferriss  17 questions that changed my life
# 2               Tim Ferriss  17 questions that changed my life
# 67  Daniel Schmachtenberger                    Dharma Inquiiry
# 6               Tim Ferriss  17 questions that changed my life
# 20              Tim Ferriss                   Tribe of Mentors
# 17              Tim Ferriss  17 questions that changed my life
# 19              Tim Ferriss                   Tribe of Mentors
# 60  Daniel Schmachtenberger                    Dharma Inquiiry
# 23              Tim Ferriss                   Tribe of Mentors
# 18              Tim Ferriss                   Tribe of Mentors
# 61  Daniel Schmachtenberger                    Dharma Inquiiry
# 81  Daniel Schmachtenberger                    Dharma Inquiiry
#
#                                                                                  Link  \
# 69                                   https://civilizationemerging.com/dharma-inquiry/
# 78                                   https://civilizationemerging.com/dharma-inquiry/
# 24                                      https://tim.blog/2017/10/03/tribe-of-mentors/
# 48                                   https://civilizationemerging.com/dharma-inquiry/
# 49                                   https://civilizationemerging.com/dharma-inquiry/
# 1   https://tim.blog/wp-content/uploads/2020/01/17-Questions-That-Changed-My-Life.pdf
# 2   https://tim.blog/wp-content/uploads/2020/01/17-Questions-That-Changed-My-Life.pdf
# 67                                   https://civilizationemerging.com/dharma-inquiry/
# 6   https://tim.blog/wp-content/uploads/2020/01/17-Questions-That-Changed-My-Life.pdf
#
# 59       If my life started over with a clean slate (no previous commitments, baggage, etc.), what would I do and how would I be differently?
# 52                                               If I was a lot more confident/ less fearful, what would I do and how would I be differently?
# 54                                                           If I had much better discipline, what would I do and how would I be differently?
# 58                                          If I had the right team and people supporting me, what would I do and how would I be differently?
# 56                                                      If I had better emotional regulation, what would I do and how would I be differently?
# 57                                               If my main character deficits were resolved, what would I do and how would I be differently?
# 27             What advice would you give to a smart, driven college student about to enter the “real world”? What advice should they ignore?
#
#     degree  betweenness  cluster
# 53      13   177.072530       16
# 55      11   108.017042       16
# 59      11   126.891142       16
# 52       9    68.567997       16
# 54       9    36.489616       16
# 58       8    12.043789       16
# 56       7     0.000000       16
# 57       7     0.000000       16
# 27       1     0.000000       16
#                      Person                 Source  \
# 36  Daniel Schmachtenberger  Civilization Emerging
# 31  Daniel Schmachtenberger  Civilization Emerging
# 45  Daniel Schmachtenberger  Civilization Emerging
# 32  Daniel Schmachtenberger  Civilization Emerging
# 33  Daniel Schmachtenberger  Civilization Emerging
# 40  Daniel Schmachtenberger  Civilization Emerging
# 47  Daniel Schmachtenberger  Civilization Emerging
# 37  Daniel Schmachtenberger  Civilization Emerging
# 42  Daniel Schmachtenberger  Civilization Emerging
# 43  Daniel Schmachtenberger  Civilization Emerging
# 44  Daniel Schmachtenberger  Civilization Emerging
# 35  Daniel Schmachtenberger  Civilization Emerging
# 38  Daniel Schmachtenberger  Civilization Emerging
# 41  Daniel Schmachtenberger  Civilization Emerging
#
#                                  Link  \
# 36  https://civilizationemerging.com/
# 31  https://civilizationemerging.com/
# 45  https://civilizationemerging.com/
# 32  https://civilizationemerging.com/
# 33  https://civilizationemerging.com/
# 40  https://civilizationemerging.com/
# 47  https://civilizationemerging.com/
# 37  https://civilizationemerging.com/
# 42  https://civilizationemerging.com/
# 43  https://civilizationemerging.com/
# 44  https://civilizationemerging.com/
# 35  https://civilizationemerging.com/
# 38  https://civilizationemerging.com/
# 41  https://civilizationemerging.com/
#
#                                                                                                                                                                                                                                                                  Question  \
# 36                                                                                                                                                                                       How would we best identify and remove perverse economic interests systemically?
# 31                                                                                                                                                           How do we create a world that is antifragile factoring increasingly decentralized exponential technologies?
# 45                                                                                                                                                    How do we comprehensively disincentivize misinformation and harm to the information ecology and epistemic commons?
# 32                                                                                 What would it take to achieve effective global coordination such that humanity could do both long range comprehensive planning and factor new information with fast processing cycles?
# 33                                                                                                                                         With the first fully globalized civilization, how do we avoid the collapse fate that has befallen all previous civilizations?
# 40                                                                                                                                                            How can we change the topology of incentive landscapes in the direction towards long term life enhancement?
# 47  Immediately, how do we make it through an increasingly multi-polar world, caught in economic extraction races as we near ecological limits of growth, empowered by increasingly catastrophic weapons and tools for increasingly effective widespread disinformation?
# 37                                                                                                                                                                   How would we best identify and remove (the basis for) corruption, without debasing creative agency?
# 42                                                                                                                                                                                                                           How can we better bind wisdom and influence?
# 43                                                                                                                                                                                       What are effective types of immune systems for corruption in governance systems?
# 44                                                                                                                                                                       How can we develop processes for collective intelligence that get smarter per capita with scale?
# 35                                                                                                                                                                               How would we best identify and internalize externalities in the decision making process?
# 38                                                                                                                                  How would we best bind predative power asymmetries where said asymmetries tend to confer the power to protect and advance themselves?
# 41                                                                                                                                                                                                                     How do we close the niches for predatory behavior?
#
#     degree  betweenness  cluster
# 36       6   889.000000       19
# 31       5   199.500000       19
# 45       4   542.000000       19
# 32       3     0.500000       19
# 33       3     0.500000       19
# 40       3   915.430505       19
# 47       3    39.500000       19
# 37       2     0.000000       19
# 42       2    82.000000       19
# 43       2     0.000000       19
# 44       2     0.000000       19
# 35       1     0.000000       19
# 38       1     0.000000       19
# 41       1     0.000000       19

# %% [markdown]
# Now, we're going to pull the graph out as an edgelist and get a feel for who is connected to who. We will then export the edgelist for import into Neo4J.

# %%
el = g.get_edge_dataframe()
el
# Out:
#          source  target
# edge ID
# 0             1       2
# 1             0       3
# 2             1       6
# 3             0      12
# 4             1      17
# ...         ...     ...
# 256          79     103
# 257          82     103
# 258          84     103
# 259          94     103
# 260          99     103
#
# [261 rows x 2 columns]

# %% [markdown]
# Now we have to convert the edges from their edge IDs to the questions that are in the order of the IDs. The reason we're seeing numbers right now is that the original adjacency matrix was made with the IDs and not the questions themselves. We're going to do that using a simple conversion function. We're going to do this by creating a dictionary.

# %%
q_dict = {}

for i in range(0, len(sentences)):
    q_dict[i] = sentences[i]

# %%
e1 = [q_dict[i] for i in el['source']]
e2 = [q_dict[i] for i in el['target']]

el_df = pd.DataFrame({'edge1': e1, 'edge2': e2})
el_df
# Out:
#                                                                                                                            edge1  \
# 0                                                   What do I spend a silly amount of money on? How might I scratch my own itch?
# 1                                                                                       What if I did the opposite for 48 hours?
# 2                                                   What do I spend a silly amount of money on? How might I scratch my own itch?
# 3                                                                                       What if I did the opposite for 48 hours?
# 4                                                   What do I spend a silly amount of money on? How might I scratch my own itch?
# ..                                                                                                                           ...
# 256  What am I naturally good at? What seems to come easy to me? (Looking at strengths and aptitudes more than specific skills.)
# 257                         What do I enjoy doing for its own sake, independent of producing results or getting acknowledgement?
# 258                                                                     What am I intrinsically fascinated by? Passionate about?
# 259                                                          Where is my sense of limited capacity constraining what I focus on?
# 260                                                                  What do I do that I wouldn’t want to be fully honest about?
#
#                                                                                                  edge2
# 0                                    What would I do/have/be if I had $10 million? What’s my real TMI?
# 1                                  What are the worst things that could happen? Could I get back here?
# 2                                    What would I do/have/be if I had $10 million? What’s my real TMI?
# 3                                  What are the worst things that could happen? Could I get back here?
# 4    How can I throw money at this problem? How can I “waste” money to improve the quality of my life?
# ..                                                                                                 ...
# 256              What do I do because I’m good at it but don’t really like it or care about it deeply?
# 257              What do I do because I’m good at it but don’t really like it or care about it deeply?
# 258              What do I do because I’m good at it but don’t really like it or care about it deeply?
# 259              What do I do because I’m good at it but don’t really like it or care about it deeply?
# 260              What do I do because I’m good at it but don’t really like it or care about it deeply?
#
# [261 rows x 2 columns]

# %%
el_df.to_csv('../output/' + dataset + '_' + model_name + '_edgelist_dist_' + str(cutoff) + '.csv', encoding='utf-8-sig')
dat.to_csv('../output/' + dataset + '_' + model_name + '_analyzed_' + str(cutoff) + '.csv', encoding='utf-8-sig')
